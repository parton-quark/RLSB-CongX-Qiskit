# %% [markdown]
# # Tutorial
# In this page, [tfc file](https://webhome.cs.uvic.ca/~dmaslov/mach-read.html) is converted to Qiskit / CongX quantum circuit.
# First, install Qiskit and CongX.

# %%
# !pip install qiskit
# !pip install CongX

# %%
from tfc_to_qiskit import tfc_to_qiskit
tfc_to_qiskit('test.tfc.txt')

# %% [markdown]
# Specify the path and import the tfc file and convert it to .py.

# %%
import RLSBCQ_test

# %% [markdown]
# The imported circuit can be handled as RLSBCQ_filename.qc.

# %%
RLSBCQ_test.qc.draw(output='mpl')

# %% [markdown]
# Transpile can also be performed as follows: If you get a good record with the original compiler, email [RLSB](https://webhome.cs.uvic.ca/~dmaslov/submit.html)!

# %%
from qiskit.compiler import transpile
transpiled = transpile(RLSBCQ_test.qc, backend=None, basis_gates=None, coupling_map=None, backend_properties=None, initial_layout=None, seed_transpiler=None, optimization_level=None, pass_manager=None, callback=None, output_name=None)
transpiled.draw(output='mpl')
