# %%
import RLSBCQ_4b15g_1

# %%
RLSBCQ_4b15g_1.qc.draw(output='mpl')

# %%
from qiskit.compiler import transpile
transpiled = transpile(RLSBCQ_4b15g_1.qc, backend=None, basis_gates=None, coupling_map=None, backend_properties=None, initial_layout=None, seed_transpiler=None, optimization_level=3, pass_manager=None, callback=None, output_name=None)
transpiled.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-6-5fae78625313> in <module>
#       1 from qiskit.compiler import transpile
# ----> 2 transpiled = transpile(RLSBCQ_4b15g_1.qc, backend=None, basis_gates=None, coupling_map=None, backend_properties=None, initial_layout=None, seed_transpiler=None, optimization_level=3, pass_manager=None, callback=None, output_name=None)
#       3 transpiled.draw(output='mpl')
#
# ~/anaconda3/lib/python3.7/site-packages/qiskit/compiler/transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     202                                   'in the coupling_map')
#     203     # Transpile circuits in parallel
# --> 204     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_configs)))
#     205
# ...
