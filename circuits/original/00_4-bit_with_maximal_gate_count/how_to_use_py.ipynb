# %%
import RLSBCQ_4b15g_1

# %%
RLSBCQ_4b15g_1.qc.draw(output='mpl')

# %%
from qiskit.compiler import transpile
transpiled = transpile(RLSBCQ_4b15g_1.qc, backend=None, basis_gates=None, coupling_map=None, backend_properties=None, initial_layout=None, seed_transpiler=None, optimization_level=None, pass_manager=None, callback=None, output_name=None)
transpiled.draw(output='mpl')
